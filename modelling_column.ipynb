# %%
# %config Completer.use_jedi = False

# %%
from scipy import stats
from scipy.stats import entropy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from itertools import groupby

# %%
np.set_printoptions(suppress=True)

# %% [markdown]
# # LOADING DATA

# %%
DIRTY_SINGLE_COLUMN_FEATURIZED_PATH = "./Datasets/Featurized/BankChurners"

# %%
dataset = pickle.load(open(f"{DIRTY_SINGLE_COLUMN_FEATURIZED_PATH}/DirtySingleColumn.pickle", "rb"))

# %%
datasets_control_novelty = dict()
datasets_control_outlier = dict()
datasets_train = dict()

for column, ds_column in dataset.items():
    datasets_control_novelty[column] = {
        'X': ds_column['control'] + ds_column['anomaly'],
        'y': [False] * len(ds_column['control']) + [True] * len(ds_column['anomaly']),
    }
    
    datasets_train[column] = {
        'X': ds_column['train'],
        'y': [False] * len(ds_column['train']),
    }
    
    datasets_control_outlier[column] = {
        'X': datasets_control_novelty[column]['X'] + datasets_train[column]['X'],
        'y': datasets_control_novelty[column]['y'] + datasets_train[column]['y'],
    }

# %% [markdown]
# # TRAIN / EVALUATE

# %%
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler
import scipy.stats as ss

# %% [markdown]
# ### ANOMALY DETECTION

# %%
algorithms_novelty = {
    'LocalOutlierFactorNovelty': LocalOutlierFactor(novelty=True),
    'OneClassSVM': OneClassSVM(),
}

algorithms_outlier = {
    'LocalOutlierFactor': LocalOutlierFactor(novelty=False),
    'IsolationForest': IsolationForest()
}

# %%
NUM_ITERATIONS = 20

# %%
def sample_from_dataset(dataset, rng, share = 0.1):
    _, counts = np.unique(dataset['y'], return_counts=True)
            
    positive_loc = np.argwhere(np.array(dataset['y']) == True).squeeze()
    negative_loc = np.argwhere(np.array(dataset['y']) == False).squeeze()

    num_negatives = counts[0]
    num_positives = int(num_negatives / (1 - share) - num_negatives)
    new_positives = rng.choice(positive_loc, num_positives)

    X_control_negatives = np.array(dataset['X'], dtype='object')[negative_loc].tolist()
    Y_control_negatives = np.array(dataset['y'], dtype='object')[negative_loc].tolist()

    X_control_positives = np.array(dataset['X'], dtype='object')[new_positives].tolist()
    Y_control_positives = np.array(dataset['y'], dtype='object')[new_positives].tolist()

    X_control_new = X_control_negatives + X_control_positives
    Y_control_new = np.r_[Y_control_negatives, Y_control_positives]
    
    return {
        'X': X_control_new,
        'y': Y_control_new,
    }

# %%
results = list()

for column in datasets_control_novelty.keys():
    for algorithm_name, algorithm in algorithms_novelty.items():
        scaler = StandardScaler()
        algorithm.fit(scaler.fit_transform(datasets_train[column]['X']))
        rng = np.random.default_rng(seed=42)
        for i in range(NUM_ITERATIONS):
            new_dataset = sample_from_dataset(datasets_control_novelty[column], rng, 0.1)
            
            control_X = scaler.transform(new_dataset['X'])

            control_score = algorithm.decision_function(control_X)
            control_prediction = algorithm.predict(control_X)

            results.append({
                "algorithm": algorithm_name,
                "column": column,
                "score": -control_score,
                "pred": (control_prediction == -1).astype(int),
                "true": new_dataset['y']
            })

# %%
for column in datasets_control_outlier.keys():
    for algorithm_name, algorithm in algorithms_outlier.items():
        rng = np.random.default_rng(seed=42)
        for i in range(NUM_ITERATIONS):
            new_dataset = sample_from_dataset(datasets_control_outlier[column], rng, 0.1)
            
            scaler = StandardScaler()
            scaler.fit(new_dataset['X'])
            
            control_prediction = algorithm.fit_predict(scaler.transform(new_dataset['X']))
            control_score = None
            
            if(hasattr(algorithm, 'decision_function')):
                control_score = algorithm.decision_function(scaler.transform(new_dataset['X']))
            elif isinstance(algorithm, LocalOutlierFactor):
                control_score = algorithm.negative_outlier_factor_
            else:    
                raise Exception(f"estimator for {column} has no decision_function")

            results.append({
                "algorithm": algorithm_name,
                "column": column,
                "score": -control_score,
                "pred": (control_prediction == -1).astype(int),
                "true": new_dataset['y']
            })

# %% [markdown]
# ### EVALUATE

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %%
results_sorted = sorted(results, key=lambda x: f"{x['algorithm']}|{x['column']}")

results_new = list()

for gr, grp in groupby(results_sorted, lambda x: f"{x['algorithm']}|{x['column']}"):
    grp = list(grp)
    results_new.append({
        'algorithm': gr.split('|')[0],
        'column': gr.split('|')[1],
        'precision': np.mean([precision_score(result['true'], result['pred']) for result in grp]),
        'recall':np.mean([recall_score(result['true'], result['pred']) for result in grp]),
        'auc': np.mean([roc_auc_score(result['true'], result['pred']) for result in grp])
    })
# Out:
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppogorelov/VirtualEnv/v2/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pd.set_option('display.max_rows', 1000)

# %%
pd.DataFrame(results_new).sort_values(by=['column', 'algorithm'])
# Out:
#                     algorithm                    column  precision  recall  \
# 0             IsolationForest            Attrition_Flag   0.612381  0.9875
# 40         LocalOutlierFactor            Attrition_Flag   0.333333  1.0000
# 20  LocalOutlierFactorNovelty            Attrition_Flag   0.850000  0.8500
# 60                OneClassSVM            Attrition_Flag   0.200000  1.0000
# 1             IsolationForest           Avg_Open_To_Buy   0.743413  1.0000
# 41         LocalOutlierFactor           Avg_Open_To_Buy   0.551984  1.0000
# 21  LocalOutlierFactorNovelty           Avg_Open_To_Buy   1.000000  1.0000
# 61                OneClassSVM           Avg_Open_To_Buy   0.142857  1.0000
# 2             IsolationForest     Avg_Utilization_Ratio   0.790556  1.0000
# 42         LocalOutlierFactor     Avg_Utilization_Ratio   0.793333  1.0000
# 22  LocalOutlierFactorNovelty     Avg_Utilization_Ratio   1.000000  1.0000
# 62                OneClassSVM     Avg_Utilization_Ratio   0.142857  1.0000
# 3             IsolationForest                 CLIENTNUM   0.923571  1.0000
# 43         LocalOutlierFactor                 CLIENTNUM   0.739048  1.0000
# 23  LocalOutlierFactorNovelty                 CLIENTNUM   1.000000  1.0000
# 63                OneClassSVM                 CLIENTNUM   0.200000  1.0000
# 4             IsolationForest             Card_Category   0.767738  0.9875
# 44         LocalOutlierFactor             Card_Category   0.517063  1.0000
# 24  LocalOutlierFactorNovelty             Card_Category   0.800000  0.8000
# 64                OneClassSVM             Card_Category   0.125000  1.0000
# 5             IsolationForest     Contacts_Count_12_mon   0.711746  1.0000
# 45         LocalOutlierFactor     Contacts_Count_12_mon   0.585495  1.0000
# 25  LocalOutlierFactorNovelty     Contacts_Count_12_mon   1.000000  1.0000
# 65                OneClassSVM     Contacts_Count_12_mon   0.111111  1.0000
# 6             IsolationForest              Credit_Limit   0.741111  1.0000
# 46         LocalOutlierFactor              Credit_Limit   0.679048  1.0000
# 26  LocalOutlierFactorNovelty              Credit_Limit   1.000000  1.0000
# 66                OneClassSVM              Credit_Limit   0.250000  1.0000
# 7             IsolationForest              Customer_Age   0.896905  1.0000
# 47         LocalOutlierFactor              Customer_Age   1.000000  1.0000
# 27  LocalOutlierFactorNovelty              Customer_Age   1.000000  1.0000
# 67                OneClassSVM              Customer_Age   0.142857  1.0000
# 8             IsolationForest           Dependent_count   0.775714  1.0000
# 48         LocalOutlierFactor           Dependent_count   0.796667  1.0000
# 28  LocalOutlierFactorNovelty           Dependent_count   1.000000  1.0000
# 68                OneClassSVM           Dependent_count   0.142857  1.0000
# 9             IsolationForest           Education_Level   0.946667  0.9875
# 49         LocalOutlierFactor           Education_Level   1.000000  1.0000
# 29  LocalOutlierFactorNovelty           Education_Level   0.800000  0.8000
# 69                OneClassSVM           Education_Level   0.111111  1.0000
# 10            IsolationForest                    Gender   0.626508  1.0000
# 50         LocalOutlierFactor                    Gender   0.571429  1.0000
# 30  LocalOutlierFactorNovelty                    Gender   0.283333  0.8500
# 70                OneClassSVM                    Gender   0.125000  1.0000
# 11            IsolationForest           Income_Category   0.925238  0.9875
# 51         LocalOutlierFactor           Income_Category   0.990000  1.0000
# 31  LocalOutlierFactorNovelty           Income_Category   0.800000  0.8000
# 71                OneClassSVM           Income_Category   0.112500  0.9000
# 12            IsolationForest            Marital_Status   0.810833  0.9875
# 52         LocalOutlierFactor            Marital_Status   0.813333  1.0000
# 32  LocalOutlierFactorNovelty            Marital_Status   0.850000  0.8500
# 72                OneClassSVM            Marital_Status   0.150000  0.9000
# 13            IsolationForest    Months_Inactive_12_mon   0.778182  1.0000
# 53         LocalOutlierFactor    Months_Inactive_12_mon   0.773810  1.0000
# 33  LocalOutlierFactorNovelty    Months_Inactive_12_mon   1.000000  1.0000
# 73                OneClassSVM    Months_Inactive_12_mon   0.142857  1.0000
# 14            IsolationForest            Months_on_book   0.807778  1.0000
# 54         LocalOutlierFactor            Months_on_book   0.960000  1.0000
# 34  LocalOutlierFactorNovelty            Months_on_book   1.000000  1.0000
# 74                OneClassSVM            Months_on_book   0.142857  1.0000
# 15            IsolationForest      Total_Amt_Chng_Q4_Q1   0.876667  1.0000
# 55         LocalOutlierFactor      Total_Amt_Chng_Q4_Q1   0.793690  0.9875
# 35  LocalOutlierFactorNovelty      Total_Amt_Chng_Q4_Q1   0.500000  1.0000
# 75                OneClassSVM      Total_Amt_Chng_Q4_Q1   0.142857  1.0000
# 16            IsolationForest       Total_Ct_Chng_Q4_Q1   0.903333  1.0000
# 56         LocalOutlierFactor       Total_Ct_Chng_Q4_Q1   0.980000  1.0000
# 36  LocalOutlierFactorNovelty       Total_Ct_Chng_Q4_Q1   1.000000  1.0000
# 76                OneClassSVM       Total_Ct_Chng_Q4_Q1   0.200000  1.0000
# 17            IsolationForest  Total_Relationship_Count   0.912222  1.0000
# 57         LocalOutlierFactor  Total_Relationship_Count   1.000000  1.0000
# 37  LocalOutlierFactorNovelty  Total_Relationship_Count   1.000000  1.0000
# 77                OneClassSVM  Total_Relationship_Count   0.125000  1.0000
# 18            IsolationForest       Total_Revolving_Bal   0.811111  1.0000
# 58         LocalOutlierFactor       Total_Revolving_Bal   0.870000  1.0000
# 38  LocalOutlierFactorNovelty       Total_Revolving_Bal   1.000000  1.0000
# 78                OneClassSVM       Total_Revolving_Bal   0.111111  1.0000
# 19            IsolationForest           Total_Trans_Amt   0.798571  1.0000
# 59         LocalOutlierFactor           Total_Trans_Amt   0.677381  1.0000
# 39  LocalOutlierFactorNovelty           Total_Trans_Amt   1.000000  1.0000
# 79                OneClassSVM           Total_Trans_Amt   0.200000  1.0000
#
#          auc
# 0   0.960625
# 40  0.900000
# 20  0.925000
# 60  0.800000
# 1   0.978750
# 41  0.958750
# 21  1.000000
# 61  0.700000
# 2   0.984375
# 42  0.985625
# 22  1.000000
# 62  0.700000
# 3   0.993750
# 43  0.981250
# 23  1.000000
# 63  0.800000
# 4   0.975000
# 44  0.951875
# 24  0.900000
# 64  0.650000
# 5   0.975000
# 45  0.953750
# 25  1.000000
# 65  0.600000
# 6   0.980000
# 46  0.975625
# 26  1.000000
# 66  0.850000
# 7   0.991875
# 47  1.000000
# 27  1.000000
# 67  0.700000
# 8   0.980000
# 48  0.986875
# 28  1.000000
# 68  0.700000
# 9   0.990000
# 49  1.000000
# 29  0.900000
# 69  0.600000
# 10  0.967500
# 50  0.962500
# 30  0.825000
# 70  0.650000
# 11  0.988125
# 51  0.999375
# 31  0.900000
# 71  0.600000
# 12  0.981250
# 52  0.988125
# 32  0.925000
# 72  0.700000
# 13  0.980625
# 53  0.984375
# 33  1.000000
# 73  0.700000
# 14  0.985000
# 54  0.997500
# 34  1.000000
# 74  0.700000
# 15  0.990000
# 55  0.977500
# 35  0.950000
# 75  0.700000
# 16  0.993125
# 56  0.998750
# 36  1.000000
# 76  0.800000
# 17  0.991250
# 57  1.000000
# 37  1.000000
# 77  0.650000
# 18  0.985000
# 58  0.991875
# 38  1.000000
# 78  0.600000
# 19  0.985000
# 59  0.973125
# 39  1.000000
# 79  0.800000
